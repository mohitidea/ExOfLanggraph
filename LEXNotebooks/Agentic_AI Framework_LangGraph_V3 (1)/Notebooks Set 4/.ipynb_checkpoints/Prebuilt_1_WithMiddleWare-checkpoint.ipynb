# %%
import os
import json
from typing import List, Dict
from langchain_core.tools import tool
from langchain_aws import ChatBedrockConverse
from langgraph.graph import StateGraph, END, START, MessagesState
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.checkpoint.memory import InMemorySaver
from rich import print

# --- Initialize LLM ---
llm = ChatBedrockConverse(
    model_id="anthropic.claude-3-sonnet-20240229-v1:0", #cohere.command-r-plus-v1:0","amazon.nova-lite-v1:0", #
    region_name="us-east-1",
    temperature=0.5,
    max_tokens=1024
)

# --- Define Tools ---
@tool
def get_weather(city: str) -> str:
    """Return a one-line weather summary for 'city'."""
    fake = {"Mysore": "23°C, partly cloudy", "New Delhi": "32°C, hot and humid", "Bangalore": "25°C, foggy"}
    return f"Weather in {city}: {fake.get(city, '20°C, clear skies')}"

@tool
def find_attractions(city: str) -> str:
    """Return a short list of top attractions for the city in JSON string form."""
    attractions = {
        "Mysore": [
            {"name": "Mysore Palace", "type": "Historical", "visit_time_mins": 90},
            {"name": "Mysore Zoo", "type": "Zoology", "visit_time_mins": 120},
        ],
        "Bangalore": [
            {"name": "LalBagh", "type": "entertainment", "visit_time_mins": 60},
        ]
    }
    return json.dumps(attractions.get(city, []))

@tool
def get_directions(origin: str, destination: str) -> str:
    """Return a short route summary for the attractions in the given city."""
    return f"Route from {origin} to {destination}: Drive ~30 mins (20 km) via Main St."

tools = [get_weather, find_attractions, get_directions]

# --- System prompt ---
system_prompt = "You are a travel assistant agent. Use all the tools to help plan trips."

# --- Create agent with HumanInTheLoopMiddleware ---
itinerary_agent = create_agent(
    model=llm,
    tools=tools,
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "get_weather": False,  # No human approval needed
                "find_attractions":{"allowed_decisions": ["approve", "edit", "reject"]},# {"allowed_decisions": ["approve", "edit", "reject"]},  # Human can approve/edit
                "get_directions":{"allowed_decisions": ["approve", "edit", "reject"]}  # Human can approve/edit
            }
        )
    ],
    checkpointer=InMemorySaver()
)

# --- Initialize StateGraph ---
workflow = StateGraph(MessagesState)

# Add the agent as a node
workflow.add_node("itinerary_agent", itinerary_agent)

# Define the workflow edges
workflow.add_edge(START, "itinerary_agent")
workflow.add_edge("itinerary_agent", END)

# Compile the graph
app = workflow.compile(checkpointer=InMemorySaver())
app

# %%
from langgraph.types import Command
import uuid

#  Generate a unique thread_id for this conversation
thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}, "recursion_limit": 10}

# Initial Execution
print(f"--- Starting Session: {thread_id} ---")
messages = [
    SystemMessage(content=system_prompt),
    HumanMessage(content="I want to visit Mysore for a trip.")
]

# Run until the first interrupt (for find_attractions)
for step in app.stream({"messages": messages}, config):
    print(step)
# Out:
# --- Starting Session: 78a2f171-28ab-46d1-aced-9912e6f8950c ---
# {
#     '__interrupt__': (
#         Interrupt(
#             value={
#                 'action_requests': [
#                     {
#                         'name': 'find_attractions',
#                         'args': {'city': 'Mysore'},
#                         'description': "Tool execution requires approval\n\nTool: find_attractions\nArgs: {'city':
# 'Mysore'}"
#                     }
#                 ],
#                 'review_configs': [
#                     {'action_name': 'find_attractions', 'allowed_decisions': ['approve', 'edit', 'reject']}
#                 ]
#             },
#             id='24a8b91f390af34ea6393dfa6610dd58'
#         ),
#     )
# }

# %%
## Run until the second interrupt(gget_directions)

# %%
resume_command = Command(resume={
    "decisions": [
        {"type": "approve"},
    ]
})

for step in app.stream(resume_command, config):
    print(step)
# Out:
# {
#     '__interrupt__': (
#         Interrupt(
#             value={
#                 'action_requests': [
#                     {
#                         'name': 'get_directions',
#                         'args': {'origin': 'Mysore city center', 'destination': 'Mysore Palace'},
#                         'description': "Tool execution requires approval\n\nTool: get_directions\nArgs: {'origin':
# 'Mysore city center', 'destination': 'Mysore Palace'}"
#                     }
#                 ],
#                 'review_configs': [
#                     {'action_name': 'get_directions', 'allowed_decisions': ['approve', 'edit', 'reject']}
#                 ]
#             },
#             id='b96d2b6d360220c2551f58c85de7c890'
#         ),
#     )
# }

# %% [markdown]
# #### Runs the tools and fetches the final response

# %%
resume_command = Command(resume={
    "decisions": [
        {"type": "approve"},
    ]
})

for step in app.stream(resume_command, config):
    print(step)
# Out:
# {
#     'itinerary_agent': {
#         'messages': [
#             SystemMessage(
#                 content='You are a travel assistant agent. Use all the tools to help plan trips.',
#                 additional_kwargs={},
#                 response_metadata={},
#                 id='90d4c495-7817-4f61-afdc-b96dd5759b4c'
#             ),
#             HumanMessage(
#                 content='I want to visit Mysore for a trip.',
#                 additional_kwargs={},
#                 response_metadata={},
#                 id='819d07cb-4d2d-489d-a168-1bd2e61f6cce'
#             ),
#             AIMessage(
#                 content=[
#                     {
#                         'type': 'text',
#                         'text': "Okay, let's plan your trip to Mysore!\n\nFirst, let's get a weather summary for
# Mysore:"
#                     },
#                     {
#                         'type': 'tool_use',
#                         'name': 'get_weather',
#                         'input': {'city': 'Mysore'},
#                         'id': 'tooluse_gMJLbmDWRgjz4y7nL9AUpK'
#                     }
#                 ],
#                 additional_kwargs={},
#                 response_metadata={
#                     'ResponseMetadata': {
#                         'RequestId': '63e04c35-8afb-47b8-9558-eb3fa4d938fb',
#                         'HTTPStatusCode': 200,
#                         'HTTPHeaders': {
#                             'date': 'Wed, 06 May 2026 03:50:37 GMT',
#                             'content-type': 'application/json',
#                             'content-length': '398',
#                             'connection': 'keep-alive',
#                             'x-amzn-requestid': '63e04c35-8afb-47b8-9558-eb3fa4d938fb'
#                         },
#                         'RetryAttempts': 0
#                     },
#                     'stopReason': 'tool_use',
#                     'metrics': {'latencyMs': [1239]},
#                     'model_provider': 'bedrock_converse',
#                     'model_name': 'anthropic.claude-3-sonnet-20240229-v1:0'
#                 },
#                 id='lc_run--019dfb68-b051-78f1-b453-b4da45abd695-0',
#                 tool_calls=[
#                     {
#                         'name': 'get_weather',
#                         'args': {'city': 'Mysore'},
#                         'id': 'tooluse_gMJLbmDWRgjz4y7nL9AUpK',
#                         'type': 'tool_call'
#                     }
#                 ],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 389,
#                     'output_tokens': 83,
#                     'total_tokens': 472,
#                     'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#                 }
#             ),
#             ToolMessage(
#                 content='Weather in Mysore: 23°C, partly cloudy',
#                 name='get_weather',
#                 id='02ccb6d7-8d33-4f72-8952-6ba08f8b8dd3',
#                 tool_call_id='tooluse_gMJLbmDWRgjz4y7nL9AUpK'
#             ),
#             AIMessage(
#                 content=[
#                     {
#                         'type': 'text',
#                         'text': "The weather looks nice for visiting Mysore. Next, let's find some top attractions
# to visit:"
#                     },
#                     {
#                         'type': 'tool_use',
#                         'name': 'find_attractions',
#                         'input': {'city': 'Mysore'},
#                         'id': 'tooluse_V7T0R5LNoyhPNDLXr5a8yW'
#                     }
#                 ],
#                 additional_kwargs={},
#                 response_metadata={
#                     'ResponseMetadata': {
#                         'RequestId': 'ad7648c5-e95e-4bba-a670-5bc93673dbf4',
#                         'HTTPStatusCode': 200,
#                         'HTTPHeaders': {
#                             'date': 'Wed, 06 May 2026 03:50:38 GMT',
#                             'content-type': 'application/json',
#                             'content-length': '407',
#                             'connection': 'keep-alive',
#                             'x-amzn-requestid': 'ad7648c5-e95e-4bba-a670-5bc93673dbf4'
#                         },
#                         'RetryAttempts': 0
#                     },
#                     'stopReason': 'tool_use',
#                     'metrics': {'latencyMs': [1404]},
#                     'model_provider': 'bedrock_converse',
#                     'model_name': 'anthropic.claude-3-sonnet-20240229-v1:0'
#                 },
#                 id='lc_run--019dfb68-b7dd-7a10-8b5c-f1546f1e9e06-0',
#                 tool_calls=[
#                     {
#                         'name': 'find_attractions',
#                         'args': {'city': 'Mysore'},
#                         'id': 'tooluse_V7T0R5LNoyhPNDLXr5a8yW',
#                         'type': 'tool_call'
#                     }
#                 ],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 497,
#                     'output_tokens': 78,
#                     'total_tokens': 575,
#                     'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#                 }
#             ),
#             ToolMessage(
#                 content='[{"name": "Mysore Palace", "type": "Historical", "visit_time_mins": 90}, {"name": "Mysore
# Zoo", "type": "Zoology", "visit_time_mins": 120}]',
#                 name='find_attractions',
#                 id='5c4622dd-58c8-4d99-a556-ee11c6d64312',
#                 tool_call_id='tooluse_V7T0R5LNoyhPNDLXr5a8yW'
#             ),
#             AIMessage(
#                 content=[
#                     {
#                         'type': 'text',
#                         'text': 'The Mysore Palace and Mysore Zoo seem to be popular attractions to check out. Let
# me map out a route for you:'
#                     },
#                     {
#                         'type': 'tool_use',
#                         'name': 'get_directions',
#                         'input': {'origin': 'Mysore city center', 'destination': 'Mysore Palace'},
#                         'id': 'tooluse_6jL0GX1gsLMF9Fray570zg'
#                     }
#                 ],
#                 additional_kwargs={},
#                 response_metadata={
#                     'ResponseMetadata': {
#                         'RequestId': '54067edd-12cc-4872-9d6a-bac19031a4b7',
#                         'HTTPStatusCode': 200,
#                         'HTTPHeaders': {
#                             'date': 'Wed, 06 May 2026 03:51:38 GMT',
#                             'content-type': 'application/json',
#                             'content-length': '468',
#                             'connection': 'keep-alive',
#                             'x-amzn-requestid': '54067edd-12cc-4872-9d6a-bac19031a4b7'
#                         },
#                         'RetryAttempts': 0
#                     },
#                     'stopReason': 'tool_use',
#                     'metrics': {'latencyMs': [1491]},
#                     'model_provider': 'bedrock_converse',
#                     'model_name': 'anthropic.claude-3-sonnet-20240229-v1:0'
#                 },
#                 id='lc_run--019dfb69-a103-7c33-8091-a7a2f0c97074-0',
#                 tool_calls=[
#                     {
#                         'name': 'get_directions',
#                         'args': {'origin': 'Mysore city center', 'destination': 'Mysore Palace'},
#                         'id': 'tooluse_6jL0GX1gsLMF9Fray570zg',
#                         'type': 'tool_call'
#                     }
#                 ],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 639,
#                     'output_tokens': 107,
#                     'total_tokens': 746,
#                     'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#                 }
#             ),
#             ToolMessage(
#                 content='Route from Mysore city center to Mysore Palace: Drive ~30 mins (20 km) via Main St.',
#                 name='get_directions',
#                 id='2774548b-c9cb-44dc-81e4-96359dac10f1',
#                 tool_call_id='tooluse_6jL0GX1gsLMF9Fray570zg'
#             ),
#             AIMessage(
#                 content="Based on the information gathered, here's a suggested itinerary for your Mysore
# trip:\n\n1. Start in the city center area \n2. Drive to the Mysore Palace, one of the top attractions - plan for
# ~90 mins there\n3. Then head to the Mysore Zoo, another highlight - budget ~2 hours there\n4. Return to city center
# area for food/shopping\n\nLet me know if you need any other details planned for your Mysore visit!",
#                 additional_kwargs={},
#                 response_metadata={
#                     'ResponseMetadata': {
#                         'RequestId': '249c6c80-59f8-4b8c-a38a-ba62e245e9a3',
#                         'HTTPStatusCode': 200,
#                         'HTTPHeaders': {
#                             'date': 'Wed, 06 May 2026 03:51:57 GMT',
#                             'content-type': 'application/json',
#                             'content-length': '613',
#                             'connection': 'keep-alive',
#                             'x-amzn-requestid': '249c6c80-59f8-4b8c-a38a-ba62e245e9a3'
#                         },
#                         'RetryAttempts': 0
#                     },
#                     'stopReason': 'end_turn',
#                     'metrics': {'latencyMs': [2616]},
#                     'model_provider': 'bedrock_converse',
#                     'model_name': 'anthropic.claude-3-sonnet-20240229-v1:0'
#                 },
#                 id='lc_run--019dfb69-e49b-7540-b284-5d91ef617802-0',
#                 tool_calls=[],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 783,
#                     'output_tokens': 109,
#                     'total_tokens': 892,
#                     'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#                 }
#             )
#         ]
#     }
# }
